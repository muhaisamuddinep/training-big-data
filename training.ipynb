# %% [markdown]
# <a href="https://colab.research.google.com/github/muhaisamuddinep/training-big-data/blob/master/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
#Membuat Variable
first_name = "John"
last_name = "Wick"
age = 38
height = 180

print(first_name + last_name)
print(last_name)
# Out:
# JohnWick
# Wick

# %%
# Operasi Aritmatika

addition = 10 + 5
print(addition)

subtraction = 10 - 5
print(subtraction)

multiplication = 10 * 5
print(multiplication)

division = 10 / 5
print(division)
# Out:
# 15
# 5
# 50
# 2.0
